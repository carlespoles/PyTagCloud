# %% [markdown]
# # 2.1.1 Machine Learning section.
#
# >In this section, we will be using the more restrictive text pre-processing:
#
# >* Porter stemming.
# * Stop words.
#
# >We will be using sklearn NaiveBayes Multinomial.

# %% [markdown]
# We have two possible labels:
#
# `relevance` and `positivity`.
#
# ** Pros of using `relevance`**:
#
# * There's no missing values. Out of 8,000 datapoints, only 9 are coded as `not sure` out of two other possible values `yes`, and `no`. I will reclassify `not sure` as `no`.
#
# * This is a binary classification problem.
#
# ** Cons of using `relevance`**:
#
# * Classes are imbalanced.
#
# ** Pros of using `positivity`**:
#
# * This is a multiclass classification problem.
#
# ** Cons of using `positivity`**:
#
# * We only have 1,420 datapoints out of 8,000 labeled.
#
# * Inputting missing values as the mean introduces bias.
#
# * There's no proper way of trying to recode the missing values as it's based on personal judgments.

# %%
reset -fs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import string
import re
import numpy as np
import pandas as pd
import seaborn as sns
import nltk
import nlp_ml_functions
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import label_binarize, MultiLabelBinarizer, binarize
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, roc_curve, mean_squared_error, r2_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition.online_lda import LatentDirichletAllocation
sns.set_style('white')

# %% [markdown]
# ## Using `relevance` as labels.

# %% [markdown]
# ### Loading dataset into a pandas dataframe.

# %%
economic_df = pd.read_csv('Full-Economic-News-DFE-839861.csv', encoding='utf-8')

# %% [markdown]
# #### Creating a list of new column names.

# %%
new_column_names = ['unit_id', 'golden', 'unit_state', 'trusted_judgments', 'last_judgment_at','positivity', 'positivity_confidence', 'relevance', 'relevance_confidence', 'article_id', 'article_date', 'article_headline', 'positivity_gold', 'relevance_gold', 'article_text']

# %% [markdown]
# #### Renaming columns of dataframe.

# %%
economic_df.columns = new_column_names

# %%
economic_df['article_headline'] = economic_df['article_headline'].apply(nlp_ml_functions.clean_up_article)

# %%
economic_df['article_text'] = economic_df['article_text'].apply(nlp_ml_functions.clean_up_article)

# %%
vectorized = TfidfVectorizer(max_features=1000, max_df=0.95, min_df=2, stop_words='english')

# %%
A_tf = vectorized.fit_transform(df.content)

# %%
lda = LatentDirichletAllocation(n_topics=4,
                                max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)

# %%
lda.fit(A_tf)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
print("Topics in LDA model:\n")
tf_feature_names = vectorized.get_feature_names()
n_top_words = 40
print_top_words(lda, tf_feature_names, n_top_words)

# %%
economic_df.shape
# Out:
# (8000, 15)

# %%
economic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 15 columns):
# unit_id                  8000 non-null int64
# golden                   8000 non-null bool
# unit_state               8000 non-null object
# trusted_judgments        8000 non-null int64
# last_judgment_at         8000 non-null object
# positivity               1420 non-null float64
# positivity_confidence    3775 non-null float64
# relevance                8000 non-null object
# relevance_confidence     8000 non-null float64
# article_id               8000 non-null object
# article_date             8000 non-null object
# article_headline         8000 non-null object
# positivity_gold          0 non-null float64
# relevance_gold           0 non-null float64
# article_text             8000 non-null object
# dtypes: bool(1), float64(5), int64(2), object(7)
# memory usage: 882.9+ KB

# %%
economic_df.relevance.value_counts()
# Out:
# no          6571
# yes         1420
# not sure       9
# Name: relevance, dtype: int64

# %% [markdown]
# #### Converting variable `relevance` to numerical values and coding `not sure` as `no`.

# %%
economic_df['relevance'] = economic_df['relevance'].apply(lambda x: 1 if x == 'yes' else 0)

# %%
economic_df.relevance.value_counts()
# Out:
# 0    6580
# 1    1420
# Name: relevance, dtype: int64

# %% [markdown]
# #### The labels/classes are clearly unbalanced.

# %%
economic_df.relevance.value_counts()*100/len(economic_df.relevance)
# Out:
# 0    82.25
# 1    17.75
# Name: relevance, dtype: float64

# %% [markdown]
# >We will experiment building models with the above class unbalance. However, we will making a new dataframe with 50% of each class.
#
# We will sample 1,200 rows of the majority class, and another 1,200 of the minority class by sampling 4 times such class with replacement.

# %% [markdown]
# #### Example of getting 1200 samples of relevance `0`.

# %%
economic_df[economic_df['relevance'] == 0].sample(n=1200)
# Out:
#         unit_id golden unit_state  trusted_judgments     last_judgment_at  \
# 4557  830982186  False  finalized                  3  11/18/2015 11:39:56
# 4221  830981850  False  finalized                  3  11/17/2015 20:44:18
# 6979  830984613  False  finalized                  3  11/18/2015 09:24:57
# 811   842614270  False  finalized                  3   12/5/2015 01:57:45
# 5960  830983590  False  finalized                  3  11/17/2015 21:43:16
# 7415  830985051  False  finalized                  3  11/17/2015 22:01:44
# 6799  830984432  False  finalized                  3  11/17/2015 18:43:37
# 7014  830984648  False  finalized                  3  11/17/2015 17:38:23
# 1121  842614580  False  finalized                  3   12/5/2015 21:01:17
# 4998  830982628  False  finalized                  3  11/17/2015 18:11:58
# 2988  842616450  False  finalized                  3   12/5/2015 03:52:55
# 4646  830982276  False  finalized                  3  11/17/2015 18:33:08
# 4137  830981766  False  finalized                  3  11/17/2015 18:15:07
# 1551  842615010  False  finalized                  3   12/5/2015 13:50:16
# 2897  842616359  False  finalized                  3   12/5/2015 20:42:57
# 1154  842614613  False  finalized                  3   12/5/2015 11:52:38
# 283   842613740  False  finalized                  3   12/5/2015 13:32:50
# 4883  830982513  False  finalized                  3  11/18/2015 09:35:54
# 171   842613627  False  finalized                  3   12/5/2015 11:59:31
# 7094  830984728  False  finalized                  3  11/17/2015 22:46:33
# 4722  830982352  False  finalized                  3  11/18/2015 04:22:20
# 1285  842614744  False  finalized                  3   12/5/2015 07:26:43
# 7677  830985313  False  finalized                  3  11/18/2015 09:39:48
# 664   842614123  False  finalized                  3   12/5/2015 11:56:32
# 72    842613527  False  finalized                  3   12/5/2015 11:43:14
# 6895  830984529  False  finalized                  3  11/18/2015 02:53:40
# 3260  842616722  False  finalized                  3   12/5/2015 05:02:32
# 2546  842616007  False  finalized                  3   12/5/2015 08:28:23
# 7291  830984926  False  finalized                  3  11/17/2015 19:38:53
# 5885  830983515  False  finalized                  3  11/17/2015 18:37:10
# ...         ...    ...        ...                ...                  ...
# 2864  842616326  False  finalized                  3   12/5/2015 08:19:22
# 3413  842616876  False  finalized                  3   12/5/2015 10:01:36
# 2199  842615660  False  finalized                  3   12/4/2015 23:51:08
# 3425  842616888  False  finalized                  3   12/5/2015 22:01:26
# 6722  830984355  False  finalized                  3  11/17/2015 20:27:33
# 7002   wapo_147289919   1980-10-29
# 4564   wapo_146576503   1976-03-14
# 7501   wapo_409982936   2006-01-30
# 4790   wapo_148915397   1957-06-09
# 854    wsj_1372303921   2013-06-29
# 5040   wapo_147984470   1970-04-05
# 2695    wsj_398500084   1994-08-15
# 832     wsj_398770673   2000-09-12
# 6708   wapo_307256839   1990-03-16
# 7073  wapo_1444592134   1997-01-19
# 585     wsj_398988497   2007-07-05
#
#                                        article_headline  positivity_gold  \
# 4557  Fed Survey: Slow Grow th, Declines: Confidence...              NaN
# 4221          Gold Tumbles on Rumors, Dollar's Strength              NaN
# 6979  School System Sending Mixed Messages, a Parent...              NaN
# 811            Curb Futures, Not Programs, Some Declare              NaN
# 5960       Federal Reserve's Chief Defends Credit Curbs              NaN
# 7415                                             DIGEST              NaN
# 6799                 QDEAR BOB: I have a FICO score ...              NaN
# 7014                   u s, GaviRiriviliT itisRANlfeEfi              NaN
# 1121           Here's Where Jobs Data Won't Be the Pits              NaN
# 4998                            How best to fight back?              NaN
# 2988  A Busy Bidder in Germany Highlights Flaws In N...              NaN
# 4646           Readers of Post Find No News Is Bad News              NaN
# 4137   West Virginia's Sales Pitch: We're Almost Heaven              NaN
# 1551  Getty Draws Initial Bids in Auction of $4 Billion              NaN
# 2897  ECB Chief Plays Down Inflation Worries --- Dui...              NaN
# 1154  Greenspan Notes Pressure on Banks To Increase ...              NaN
# 283   Housing market, consumer confidence improve wh...              NaN
# 4883  California Legislature Closes In on Budget Def...              NaN
# 171   Ultrashort Bond Funds: Are They Ultrasafe?; Th...              NaN
# 7094            Markets End Second Straight Losing Week              NaN
# 4722  Incomes, Home Sales Rise, But Spending Off in ...              NaN
# 1285            Stocks Hit High Gear With Boost From GM              NaN
# 7677   Russia's President Faces an Uneasy U.S. Congress              NaN
# 664                                Tracking the Economy              NaN
# 72      Long-Term Unemployment Ripples Through One Town              NaN
# 6895  World: Japan Gears Up to Prevent American-Styl...              NaN
# 3260  Futures Markets: Rate Contracts Plunge On Infl...              NaN
# 2546  U.S. News: Existing-Home Sales Fall; Backlog S...              NaN
# 7291       Stock Prices Decline; Profit Taking Is Cited              NaN
# 5885  Stock Market Closes Mixed; Dow Average Up 11.2...              NaN
# ...                                                 ...              ...
# 2864  Companies' Layoff Plans Contradict Economists'...              NaN
# 3413        Bonds Stumble Amid Concerns Rates Will Rise              NaN
# 2199  Are Capital Pains In Store?; Paulson's Plan Fo...              NaN
# 3425  Fed Adds 175 Stocks To Its Margin List, Drops ...              NaN
# 6722                  Dow Gains 4; Rest of Market Mixed              NaN
# 3285  Mutual Funds/Managed Investing: Most Funds Lag...              NaN
# 2196            WEEKEND JOURNAL; Home Prices: Our Towns              NaN
# 3508  Bond Prices Decline in Lighter Trading As Inve...              NaN
# 527                     Bernanke Makes Case to Senators              NaN
# 4360                   Inflation Increases As Energ ...              NaN
# 4627  Yen Worries Send Japanese Finance Ministry Off...              NaN
# 5728                 Local firms cautiously plan growth              NaN
# 1304  Natural Gas Tumbles As Crude Oil Slides; Hurri...              NaN
# 2161                         Pro-Trade, Pro-Immigration              NaN
# 2188     Card Tricks Win Big Rewards for Some Travelers              NaN
# 3529  Cap Gemini Cuts Forecasts Again For Sales, Profit              NaN
# 4643        Brimmer: Empnusis on Money Supply Dangerous              NaN
# 6492  GOP finds grist for campaigns in projections o...              NaN
# 3127                 The Magnitude of the Mess We're In              NaN
# 7002               Export Drop Helps Trade Deficit Grow              NaN
# 4564                           Travel Sweepstakes, 1976              NaN
# 7501          Answer Man: A New View of 'The Awakening'              NaN
# 4790                             Steels, Chemicals Gain              NaN
# 854   WEEKEND INVESTOR --- Where to Invest in an Era...              NaN
# 5040                    Building Freeze Lift Criticized              NaN
# 2695  Probable interest-rate increase by Fed won't n...              NaN
# 832       Fed Official Says Rates Could Soon Move Lower              NaN
# 6708  Darman Remains Elusive on Tax Compromise;Budge...              NaN
# 7073  your Money: 10 Stocks to Ponder for a 1997 Por...              NaN
# 585                                   Ahead of the Tape              NaN
#
#       relevance_gold                                       article_text
# 4557             NaN  A national economic snapshot taken in early Oc...
# 4221             NaN  Gold prices plunged yesterday as a strong doll...
# 6979             NaN  I have to wonder whether our school system und...
# 811              NaN  NEW YORK -- As program trading comes under ren...
# 5960             NaN  Chairman William McChes-ney .Martin Jr. yester...
# 7415             NaN  Cosco, a maker of children's furniture, settle...
# 6799             NaN  QDEAR BOB: I have a FICO score of 750 and wond...
# 7014             NaN  Offers daily liquidity, monthly payments and d...
# 1121             NaN  CHICAGO -- Here at the world's biggest futures...
# 4998             NaN  The D.C. Council is preparing some of the nati...
# 2988             NaN  DUISBURG, Germany -- In Germany's much-vaunted...
# 4646             NaN  Washington-area residents ranging from stock m...
# 4137             NaN  Balloons bobbed, the crowd cheered and the loc...
# 1551             NaN  The auction for a potential sale of Getty Imag...
# 2897             NaN  FRANKFURT -- European Central Bank President W...
# 1154             NaN  WASHINGTON -- Federal Reserve Board Chairman A...
# 283              NaN  WASHINGTON -- More than four years into the ec...
# 4883             NaN  SACRAMENTO, Calif., July 3— Under prodding fro...
# 171              NaN  With short-term interest rates remaining locke...
# 7094             NaN  Stock markets rebounded Friday as General Elec...
# 4722             NaN  Personal income and new-home sales rose for th...
# 1285             NaN  NEW YORK -- General Motors Corp. put some sizz...
# 7677             NaN  Instead of a big package of aid for his countr...
# 664              NaN  TECHNICAL DATA ECONOMIC RELEASE PREVIOUS CONSE...
# 72               NaN  ROSWELL, Ga. -- The waiting list for subsidize...
# 6895             NaN  ‘Japan soon will unveil an eight-point program...
# 3260             NaN  Interest-rate futures plummeted in response to...
# 2546             NaN  Sales of previously owned homes declined in Au...
# 7291             NaN  * NEW YORK, Sept. 10 — Investors in a profit-t...
# 5885             NaN  Prices closed mixed on Wall Street today, bols...
# ...              ...                                                ...
# 2864             NaN  The recession, most economists agree, is over....
# 3413             NaN  Stocks pulled back and Treasury bonds plummete...
# 2199             NaN  Treasury Secretary Henry Paulson's non-nationa...
# 3425             NaN  WASHINGTON -- The Federal Reserve Board added ...
# 6722             NaN  NEW YORK, Dec. 6—The stock market struggled to...
# 3285             NaN  Most mutual funds lagged the market in the tur...
# 2196             NaN  [As home prices soar, we survey more than 1,00...
# 3508             NaN  NEW YORK -- Bond prices declined yesterday, sn...
# 527              NaN  Author: Luca Di Leo; Corey Boles</br></br>Fede...
# 4360             NaN  Rising energy prices pushed U.S. consumer infl...
# 4627             NaN  A top official at the Japanese Finance Ministr...
# 5728             NaN  Washington area companies are coming out of th...
# 1304             NaN  NEW YORK -- Natural-gas futures made their big...
# 2161             NaN  Tuesday night was not a good one for Republica...
# 2188             NaN  Want a free trip to Paris?</br></br>Just sign ...
# 3529             NaN  PARIS -- Cap Gemini Ernst & Young warned that ...
# 4643             NaN  (The (nlloicinci is enrolled from 'I'\ dcral R...
# 6492             NaN  The federal budget deficit, which hit a record...
# 3127             NaN  Sometimes a few facts tell important stories. ...
# 7002             NaN  A drop in exports coupled with a sharp rise in...
# 4564             NaN  With a bottoming out of the U.S. recession, Am...
# 7501             NaN  In his Jan. 9 column about "The Awakening" sta...
# 4790             NaN  The oils resumed their leadership early in the...
# 854              NaN  It is time for investors to rethink safety.</b...
# 5040             NaN  will be seen today on the of the 42d annual Ge...
# 2695             NaN  CHICAGO -- After a summer of calling for the F...
# 832              NaN  CHICAGO -- One of the Federal Reserve's leadin...
# 6708             NaN  When Bush administration budget director Richa...
# 7073             NaN  firt’s a safe bet we'll never see I another tw...
# 585              NaN  Can Techs</br></br>Pick Up Slack</br></br>In S...
#
# [1200 rows x 15 columns]

# %% [markdown]
# #### Example of getting 300 samples of relevance `1` with replacement.

# %%
economic_df[economic_df['relevance'] == 1].sample(n=300, replace=True)
# Out:
#         unit_id golden unit_state  trusted_judgments     last_judgment_at  \
# 2410  842615871  False  finalized                  3   12/5/2015 02:41:52
# 3045  842616507  False  finalized                  3   12/4/2015 23:38:53
# 1684  842615143  False  finalized                  3   12/5/2015 22:36:45
# 4055  830981684  False  finalized                  3  11/18/2015 11:39:51
# 3476  842616939  False  finalized                  3   12/5/2015 13:57:09
# 365   842613823  False  finalized                  3   12/5/2015 01:26:25
# 1343  842614802  False  finalized                  3   12/5/2015 04:30:14
# 7848  830985485  False  finalized                  3  11/17/2015 17:38:31
# 2481  842615942  False  finalized                  3   12/4/2015 22:59:03
# 1968  842615428  False  finalized                  3   12/5/2015 00:08:33
# 240   842613697  False  finalized                  3   12/5/2015 18:34:35
# 2393  842615854  False  finalized                  3   12/5/2015 17:55:56
# 6488  830984119  False  finalized                  3  11/18/2015 08:50:14
# 2073  842615533  False  finalized                  3   12/5/2015 20:06:43
# 1391  842614850  False  finalized                  3   12/5/2015 00:11:37
# 1030  842614489  False  finalized                  3   12/5/2015 22:07:10
# 5197  830982827  False  finalized                  3  11/17/2015 20:13:28
# 172   842613628  False  finalized                  3   12/5/2015 13:32:12
# 5001  830982631  False  finalized                  3  11/18/2015 12:15:47
# 6249  830983880  False  finalized                  3  11/17/2015 18:49:41
# 2995  842616457  False  finalized                  3   12/5/2015 23:10:18
# 1834    wsj_398031611   1988-03-18
# 3971    wsj_762234420   2010-11-03
# 4155   wapo_307829944   1995-06-29
# 3450    wsj_398936478   2005-06-09
# 1834    wsj_398031611   1988-03-18
# 2873    wsj_849776453   2011-02-09
# ...               ...          ...
# 3468   wsj_1638898330   2014-12-22
# 7509   wapo_409398573   2003-02-08
# 6282   wapo_147744641   1970-04-19
# 2732   wsj_1543603523   2014-07-09
# 54      wsj_399048542   2009-01-16
# 1262    wsj_398877540   2003-06-27
# 4243   wapo_408410427   1998-09-12
# 1465    wsj_398033880   1988-04-27
# 407     wsj_398682668   1996-03-25
# 407     wsj_398682668   1996-03-25
# 7229   wapo_147325385   1981-08-08
# 7192   wapo_408528134   1999-09-06
# 196     wsj_398840569   2003-05-29
# 6217   wapo_410244720   2008-01-19
# 3925    wsj_398991544   2007-11-01
# 210    wsj_1612103616   2014-10-16
# 7567  wapo_1033942200   1996-11-02
# 2627    wsj_397930998   1984-02-07
# 940    wsj_1541951857   2014-07-02
# 2271    wsj_399026228   2007-09-05
# 4530   wapo_138086972   1983-01-25
# 6428   wapo_142150001   1964-09-20
# 5497   wapo_142878809   1966-10-11
# 5437   wapo_142984425   1966-11-25
# 3522    wsj_398771249   1999-02-02
# 4117   wapo_139121505   1987-06-06
# 6446   wapo_408523708   1999-10-26
# 5677   wapo_139250817   1987-10-20
# 2730    wsj_398711822   1997-04-18
# 7265   wapo_140365411   1991-03-24
#
#                                        article_headline  positivity_gold  \
# 2410  The Unloved Buck: Dollar's Fall Threatens U.S....              NaN
# 3045  Cost-Cutting Airlines Grapple With Issue of Ex...              NaN
# 1684  'Correction' Corrects Itself by Day's End; Bea...              NaN
# 4055  3.5%. Benefit Rise Set Under Social Security: ...              NaN
# 3476                                  Ahead of the Tape              NaN
# 365     Dollar Declines In Face of Lower Interest Rates              NaN
# 1343  Most Interest Rates End Little Changed As Oil ...              NaN
# 7848  Market Registers Week's Fourth Gain As Corpora...              NaN
# 2481    Expect the World Economy to Suffer Through 2009              NaN
# 1968  Producer Prices Increased 0.4% For December --...              NaN
# 240   Stocks Edge Higher, Ignoring Bad News On Econo...              NaN
# 2393                               Business and Finance              NaN
# 6488  U.S. Experts Watching As Britain Issues Securi...              NaN
# 2073                          A Portrait of the Economy              NaN
# 1391            America Inc. Wakes Up to Wage Inflation              NaN
# 1030                                  Ahead of the Tape              NaN
# 5197     Dow Falls 17; Technology Stocks Take a Beating              NaN
# 172   Wednesday's markets: Stocks mixed, bonds decli...              NaN
# 5001  Sharp Pickup in U.S. Economy Reported by Reser...              NaN
# 6249  THE WASHINGTON POST Wednesday, March 10, IQiJ'J                NaN
# 2995  Update on How Some Firms, Programs Progressed ...              NaN
# 2745  U.S. News: Hopes for a Turnaround Grow Dimmer ...              NaN
# 3008                                  Ahead of the Tape              NaN
# 2122  Retail Issues Follow Techs Down; Talbots, Gap,...              NaN
# 1834  Trade Deficit Widened a Bit During January ---...              NaN
# 3971  Milton Friedman vs. the Fed; The Nobel laureat...              NaN
# 4155  TITLE XX REVISITED; An '80s Parallel On Cuttin...              NaN
# 3450     Heartland, Werner Decline on Analyst Downgrade              NaN
# 1834  Trade Deficit Widened a Bit During January ---...              NaN
# 2873      McDonald's Helps Push the Dow to 2-Year Highs              NaN
# ...                                                 ...              ...
# 3468  U.S. Government Bonds Strengthen; Treasurys on...              NaN
# 7509                 Stocks Slump With Code Orange News              NaN
# 6282                            Slower Price Rises Seen              NaN
# 2732                                  Ahead of the Tape              NaN
# 54    U.S. News: Producer Prices Log Another Monthly...              NaN
# 1262     Initial Jobless Claims Drop to Three-Month Low              NaN
# 4243  Social Security `Privatizers' Unbowed; Rethink...              NaN
# 1465  Dollar Gains Slightly After GNP Report Meets E...              NaN
# 407              U.S. budget defict widened in February              NaN
# 407              U.S. budget defict widened in February              NaN
# 7229  Jobless Rate Declines to7 Percent: July Statis...              NaN
# 7192                    Workers Should Back Lower Taxes              NaN
# 196   Left Behind -- Casualties of a Changing Job Ma...              NaN
# 6217  A Tougher Tone at the Top; Bernanke Answers Cr...              NaN
# 3925  Dollar Drops Further Vs. Euro on Rate Cut; Can...              NaN
# 210                       A Year of Living on the Brink              NaN
# 7567  Jobless Rate Steady at 5.2: Clinton Camp Revel...              NaN
# 2627  Futures Markets: Foreign Currencies Fall as Tr...              NaN
# 940               OCC Data Reaffirm Wall Street Warning              NaN
# 2271           The Afternoon Report: The Newest Numbers              NaN
# 4530  The Good News And Bad on Oil: Good Bad Seen in...              NaN
# 6428          Profit Taking Follows Tonkin Bay Incident              NaN
# 5497         Jobless Down To 3.8% Rate as Schools Start              NaN
# 5437  Drab News Depresses Market: News Helped Averag...              NaN
# 3522                                The Lewinsky Budget              NaN
# 4117                                        ROUNDUP /                NaN
# 6446  Stocks Fall As Bond Yields Rise; Dow Closes Of...              NaN
# 5677                       Washington Post Stall writer              NaN
# 2730  Trade deficit narrowed in February, as aircraf...              NaN
# 7265                        Post-War Reality Re-Visited              NaN
#
#       relevance_gold                                       article_text
# 2410             NaN  A global run on the dollar, which is shaking u...
# 3045             NaN  A HARSH DOWNDRAFT grips the U.S. airline indus...
# 1684             NaN  The stock market went into "correction" mode y...
# 4055             NaN  3.5\tpercent next year and Social Security tax...
# 3476             NaN  [Today's Market Forecast]</br></br>Beware the ...
# 365              NaN  The U.S. dollar declined against major foreign...
# 1343             NaN  NEW YORK -- Most interest rates wound up littl...
# 7848             NaN  NEW YORK, June 16—xne stock market jumped high...
# 2481             NaN  Some optimistic experts are now saying that th...
# 1968             NaN  WASHINGTON -- The Labor Department's December ...
# 240              NaN  MOST STOCKS shrugged off bad news on the econo...
# 2393             NaN  THE GROUP OF SEVEN reaffirmed its dollar-stabi...
# 6488             NaN  In a high-stakes gamble that is being watched ...
# 2073             NaN  It's the best of times. It's the scariest of t...
# 1391             NaN  Even as the U.S. job market has improved, comp...
# 1030             NaN  [Today's Market Forecast]</br></br>Out of Orde...
# 5197             NaN  . NEW YORK, Jan. 15—Technology stocks undermin...
# 172              NaN  Stock prices finished mixed, dragged down by r...
# 5001             NaN  The Federal Reserve Board yesterday pictured t...
# 6249             NaN  Depending upon what figures we read, unemploym...
# 2995             NaN  ON THE WHOLE, 1985 has been kind to small busi...
# 2745             NaN  Americans are earning more money -- but sockin...
# 3008             NaN  More Cuts</br></br>From the Fed</br></br>Seem ...
# 2122             NaN  NEW YORK -- Retail issues faltered, joining hi...
# 1834             NaN  WASHINGTON -- The nation's merchandise trade d...
# 3971             NaN  Author: Allan H. Meltzer</br></br>Would the la...
# 4155             NaN  If the welfare debate has a familiar ring, it'...
# 3450             NaN  Dow Jones Newswires</br></br>Small stocks gave...
# 1834             NaN  WASHINGTON -- The nation's merchandise trade d...
# 2873             NaN  NEW YORK -- The consumer sector led U.S. stock...
# ...              ...                                                ...
# 3468             NaN  Benchmark Treasury bonds strengthened on Monda...
# 7509             NaN  U.S. stocks fell, leaving benchmark indexes wi...
# 6282             NaN  White House economist Paul W. McCracken, denyi...
# 2732             NaN  Uncertainty Abounds Around Rate Rise</br></br>...
# 54               NaN  U.S. wholesale prices sank further last month,...
# 1262             NaN  WASHINGTON -- The number of U.S. workers filin...
# 4243             NaN  The unnerving spectacle of the stock market sh...
# 1465             NaN  NEW YORK -- An unsurprising report on U.S. gro...
# 407              NaN  WASHINGTON -- The federal government posted a ...
# 407              NaN  WASHINGTON -- The federal government posted a ...
# 7229             NaN  ' The nation's unemployment rate fell to 7 per...
# 7192             NaN  As America observes the century's last Labor D...
# 196              NaN  [Fourth in a Series]</br></br>Economist Robert...
# 6217             NaN  When Ben S. Bernanke became Federal Reserve ch...
# 3925             NaN  NEW YORK -- The dollar dropped to its seventh ...
# 210              NaN  History will mark down 2014 as the year predic...
# 7567             NaN  The last major economic report due before Elec...
# 2627             NaN  Foreign-currency futures plunged as traders to...
# 940              NaN  WASHINGTON -- A U.S. regulator said banks' tra...
# 2271             NaN  Economy watchers, trying to triangulate the ec...
# 4530             NaN  The growing possibility of a sharp decline in ...
# 6428             NaN  Troubled waters of the Bay of Tonkin rippled t...
# 5497             NaN  The Nation’s unemployment rate dipped to 3.8 p...
# 5437             NaN  I NEW YORK, Nov. 22 lAl’li The stock market re...
# 3522             NaN  One of the great moments from the Starr Report...
# 4117             NaN  a A surge in revolving credit charges and auto...
# 6446             NaN  Stocks closed mostly lower today as revived fe...
# 5677             NaN  Washington area investor^ showed little sign o...
# 2730             NaN  WASHINGTON -- The U.S. trade deficit in goods ...
# 7265             NaN  market had a remarkable rise once the bombs st...
#
# [300 rows x 15 columns]

# %% [markdown]
# >Now, let's create a new dataframe with the balanced sampling:

# %%
frames = []
for i in range(5):
    if i < 4:
        frames.append(economic_df[economic_df['relevance'] == 1].sample(n=300, replace=True))
    else:
        frames.append(economic_df[economic_df['relevance'] == 0].sample(n=1200, replace=False))
    
balanced_df = pd.concat(frames)

# %%
balanced_df.relevance.value_counts()*100/len(balanced_df.relevance)
# Out:
# 1    50.0
# 0    50.0
# Name: relevance, dtype: float64

# %% [markdown]
# >We have a balanced dataframe to build future models.

# %% [markdown]
# #### Converting variable `unit_state` to numerical values.

# %%
economic_df['unit_state'] = economic_df['unit_state'].apply(lambda x: 1 if x == 'finalized' else 0)

# %%
balanced_df['unit_state'] = balanced_df['unit_state'].apply(lambda x: 1 if x == 'finalized' else 0)

# %% [markdown]
# #### Converting variable `golden` to numerical values.

# %%
economic_df['golden'] = economic_df['golden'].apply(lambda x: 0 if x == False else 1)

# %%
balanced_df['golden'] = balanced_df['golden'].apply(lambda x: 0 if x == False else 1)

# %% [markdown]
# #### Since columns `positivity_gold` and `relevance_gold` are empty, we can drop them.

# %%
del economic_df['positivity_gold']

# %%
del balanced_df['positivity_gold']

# %%
del economic_df['relevance_gold']

# %%
del balanced_df['relevance_gold']

# %% [markdown]
# #### Converting `last_judgment_at` and `article_date` to datetime.

# %%
economic_df['last_judgment_at'] = pd.to_datetime(economic_df['last_judgment_at'])

# %%
balanced_df['last_judgment_at'] = pd.to_datetime(balanced_df['last_judgment_at'])

# %%
economic_df['article_date'] = pd.to_datetime(economic_df['article_date'])

# %%
balanced_df['article_date'] = pd.to_datetime(balanced_df['article_date'])

# %% [markdown]
# ### Clean up.

# %%
economic_df['article_headline'] = economic_df['article_headline'].apply(nlp_ml_functions.clean_up_article)

# %%
balanced_df['article_headline'] = balanced_df['article_headline'].apply(nlp_ml_functions.clean_up_article)

# %%
economic_df['article_text'] = economic_df['article_text'].apply(nlp_ml_functions.clean_up_article)

# %%
balanced_df['article_text'] = balanced_df['article_text'].apply(nlp_ml_functions.clean_up_article)

# %% [markdown]
# ## 1- Creating models with unbalanced labels dataframe.

# %%
X_headline = economic_df['article_headline']
y_headline = economic_df['relevance']

# %%
X_train_headline, X_test_headline, y_train_headline, y_test_headline = train_test_split(X_headline, y_headline, test_size=0.3, random_state=42)

# %%
X_article = economic_df['article_text']
y_article = economic_df['relevance']

# %%
X_train_article, X_test_article, y_train_article, y_test_article = train_test_split(X_article, y_article, test_size=0.3, random_state=42)

# %% [markdown]
# ### 1.1 - Applying CountVectorizer.
#
# We will apply to `article_headline` and `article_text`.

# %%
pipeline = Pipeline([('bow', CountVectorizer(analyzer=nlp_ml_functions.process_dataframe_text)),('classifier', MultinomialNB())])

# %%
pipeline.fit(X_train_headline, y_train_headline)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preproce...None, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_headline)

# %% [markdown]
# #### Model evaluation using headlines.

# %%
nlp_ml_functions.plot_roc(y_test_headline, predictions, "CountVectorizer - Multinomial NB", "Headlines Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_headline, predictions), ['Class 0', 'Class 1'])

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_headline, predictions)
# Out:
# Precision Score of Multinomial NB model: 45.60%
#
# AUC: 54.76%
#
# Accuracy Score of Multinomial NB model: 81.25%
#
# Recall Score of Multinomial NB model: 12.98%
#
# F1 Score of Multinomial NB model: 20.21%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.83      0.97      0.89      1961
#           1       0.46      0.13      0.20       439
#
# avg / total       0.76      0.81      0.77      2400

# %%
pipeline.fit(X_train_article, y_train_article)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preproce...None, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_article)

# %% [markdown]
# #### Model evaluation using article.

# %%
nlp_ml_functions.plot_roc(y_test_article, predictions, "CountVectorizer - Multinomial NB", "Article Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_article, predictions), ['Class 0', 'Class 1'])

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_article, predictions)
# Out:
# Precision Score of Multinomial NB model: 39.83%
#
# AUC: 57.24%
#
# Accuracy Score of Multinomial NB model: 79.67%
#
# Recall Score of Multinomial NB model: 21.87%
#
# F1 Score of Multinomial NB model: 28.24%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.84      0.93      0.88      1961
#           1       0.40      0.22      0.28       439
#
# avg / total       0.76      0.80      0.77      2400

# %% [markdown]
# ### 1.2 - Applying TfidfVectorizer.

# %%
pipeline = Pipeline([('bow', TfidfVectorizer(analyzer=nlp_ml_functions.process_dataframe_text)),('classifier', MultinomialNB())])

# %%
pipeline.fit(X_train_headline, y_train_headline)
# Out:
# Pipeline(steps=[('bow', TfidfVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), norm='l2...      vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_headline)

# %% [markdown]
# #### Model evaluation using headlines.

# %%
nlp_ml_functions.plot_roc(y_test_headline, predictions, "Tfidf - Multinomial NB", "Headlines Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_headline, predictions), ['Class 0', 'Class 1'])

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_headline, predictions)
# Out:
# Precision Score of Multinomial NB model: 100.00%
#
# AUC: 50.11%
#
# Accuracy Score of Multinomial NB model: 81.75%
#
# Recall Score of Multinomial NB model: 0.23%
#
# F1 Score of Multinomial NB model: 0.45%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.82      1.00      0.90      1961
#           1       1.00      0.00      0.00       439
#
# avg / total       0.85      0.82      0.74      2400

# %%
pipeline.fit(X_train_article, y_train_article)
# Out:
# Pipeline(steps=[('bow', TfidfVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), norm='l2...      vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_article)

# %% [markdown]
# #### Model evaluation using article.

# %%
nlp_ml_functions.plot_roc(y_test_article, predictions, "Multinomial NB", "Articles Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_article, predictions), ['Class 0', 'Class 1'])
# Out:
# /Users/carles/DSCI6004-student/week_8/8_2_final_project/FinalProject-CPM/nlp_ml_functions.py:219: RuntimeWarning: invalid value encountered in true_divide
#   'Pos Pred Val: %.2f'%(tp/(tp+fp+0.)),

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_article, predictions)
# Out:
# Precision Score of Multinomial NB model: 0.00%
#
# AUC: 50.00%
#
# Accuracy Score of Multinomial NB model: 81.71%
#
# Recall Score of Multinomial NB model: 0.00%
#
# F1 Score of Multinomial NB model: 0.00%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.82      1.00      0.90      1961
#           1       0.00      0.00      0.00       439
#
# avg / total       0.67      0.82      0.73      2400
# //anaconda/envs/nlp/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# //anaconda/envs/nlp/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# //anaconda/envs/nlp/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## 2- Creating models with balanced labels dataframe.

# %%
X_headline = balanced_df['article_headline']
y_headline = balanced_df['relevance']

# %%
X_train_headline, X_test_headline, y_train_headline, y_test_headline = train_test_split(X_headline, y_headline, test_size=0.3, random_state=42)

# %%
X_article = balanced_df['article_text']
y_article = balanced_df['relevance']

# %%
X_train_article, X_test_article, y_train_article, y_test_article = train_test_split(X_article, y_article, test_size=0.3, random_state=42)

# %% [markdown]
# ### 2.1 - Applying CountVectorizer.

# %%
pipeline = Pipeline([('bow', CountVectorizer(analyzer=nlp_ml_functions.process_dataframe_text)),('classifier', MultinomialNB())])

# %%
pipeline.fit(X_train_headline, y_train_headline)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preproce...None, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_headline)

# %% [markdown]
# #### Model evaluation using headlines.

# %%
nlp_ml_functions.plot_roc(y_test_headline, predictions, "CountVectorizer - Multinomial NB", "Headlines Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_headline, predictions), ['Class 0', 'Class 1'])

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_headline, predictions)
# Out:
# Precision Score of Multinomial NB model: 65.36%
#
# AUC: 68.53%
#
# Accuracy Score of Multinomial NB model: 68.75%
#
# Recall Score of Multinomial NB model: 81.97%
#
# F1 Score of Multinomial NB model: 72.73%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.75      0.55      0.63       354
#           1       0.65      0.82      0.73       366
#
# avg / total       0.70      0.69      0.68       720

# %%
pipeline.fit(X_train_article, y_train_article)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preproce...None, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_article)

# %% [markdown]
# #### Model evaluation using article.

# %%
nlp_ml_functions.plot_roc(y_test_article, predictions, "CountVectorizer - Multinomial NB", "Articles Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_article, predictions), ['Class 0', 'Class 1'])

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_article, predictions)
# Out:
# Precision Score of Multinomial NB model: 70.54%
#
# AUC: 74.53%
#
# Accuracy Score of Multinomial NB model: 74.72%
#
# Recall Score of Multinomial NB model: 86.34%
#
# F1 Score of Multinomial NB model: 77.64%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.82      0.63      0.71       354
#           1       0.71      0.86      0.78       366
#
# avg / total       0.76      0.75      0.74       720

# %% [markdown]
# ### 2.2 - Applying TfidfVectorizer.

# %%
pipeline = Pipeline([('bow', TfidfVectorizer(analyzer=nlp_ml_functions.process_dataframe_text)),('classifier', MultinomialNB())])

# %%
pipeline.fit(X_train_headline, y_train_headline)
# Out:
# Pipeline(steps=[('bow', TfidfVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), norm='l2...      vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_headline)

# %% [markdown]
# #### Model evaluation using headlines.

# %%
nlp_ml_functions.plot_roc(y_test_headline, predictions, "TfidfVectorizer - Multinomial NB", "Headlines Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_headline, predictions), ['Class 0', 'Class 1'])

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_headline, predictions)
# Out:
# Precision Score of Multinomial NB model: 65.11%
#
# AUC: 68.64%
#
# Accuracy Score of Multinomial NB model: 68.89%
#
# Recall Score of Multinomial NB model: 83.61%
#
# F1 Score of Multinomial NB model: 73.21%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.76      0.54      0.63       354
#           1       0.65      0.84      0.73       366
#
# avg / total       0.70      0.69      0.68       720

# %%
pipeline.fit(X_train_article, y_train_article)
# Out:
# Pipeline(steps=[('bow', TfidfVectorizer(analyzer=<function process_dataframe_text at 0x113d08ae8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), norm='l2...      vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(X_test_article)

# %% [markdown]
# #### Model evaluation using article.

# %%
nlp_ml_functions.plot_roc(y_test_article, predictions, "TfidfVectorizer - Multinomial NB", "Articles Relevance")

# %%
nlp_ml_functions.show_confusion_matrix(confusion_matrix(y_test_article, predictions), ['Class 0', 'Class 1'])

# %%
nlp_ml_functions.classification_metrics("Multinomial NB", y_test_article, predictions)
# Out:
# Precision Score of Multinomial NB model: 67.71%
#
# AUC: 72.51%
#
# Accuracy Score of Multinomial NB model: 72.78%
#
# Recall Score of Multinomial NB model: 88.80%
#
# F1 Score of Multinomial NB model: 76.83%
#
# Classification Report of Multinomial NB:
#
#               precision    recall  f1-score   support
#
#           0       0.83      0.56      0.67       354
#           1       0.68      0.89      0.77       366
#
# avg / total       0.75      0.73      0.72       720

# %% [markdown]
# ### We have learned that is best to use the balance labels dataset, that using articles is better than headlines (as they have less features) and that CountVectorizer has better metrics than TfidfVectorizer.
