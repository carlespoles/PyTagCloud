# %% [markdown]
# # Unsupervised Learning - Creating a WordCloud.
#
# Using LDA (LatentDirichletAllocation), we will apply it to the articles headlines to create a wordcloud.
#
# The PyTagCloud library has been used (https://github.com/atizo/PyTagCloud) and updated a few lines of code to Python 3.

# %%
reset -fs

# %%
import os
import webbrowser
from pytagcloud import create_tag_image, make_tags
from pytagcloud.lang.counter import get_tag_counts
import matplotlib.pyplot as plt
# %matplotlib inline
import string
import re
import numpy as np
import pandas as pd
import seaborn as sns
import nltk
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import label_binarize, MultiLabelBinarizer, binarize
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, roc_curve, mean_squared_error, r2_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition.online_lda import LatentDirichletAllocation
sns.set_style('white')

# %%
def clean_up_article(article):
    """
    Function to remove HTML characters </br> and replace n\\'t with not, it\\s with it is, and \\'s with s.
    """
    article = re.sub('</br>','', article)
    article = re.sub("(n\\'t)","not", article)
    article = re.sub("(it\\'s)","it is", article)
    article = re.sub("(\\'s)","s", article)
    article = re.sub("(\\t)"," ", article)
    return article

# %%
def process_dataframe_text(article):
    """
    Function that takes text from a dataframe and 1st removes punctuation, 2nd removes stopwords and converts
    into lower case, and finally using PorterStemmer, stems the words, returning a list of the processed text in lowercase.
    """
    stemmer = nltk.stem.PorterStemmer()
    
    # Removing punctuation by checking every character in the text passed to the function.
    remove_punctuation = [char for char in article if char not in string.punctuation]

    # Once punctuation has been removed, we join them again to form a string.
    remove_punctuation = ''.join(remove_punctuation)
    
    # Removing stopwords and converting to lower case.
    remove_stop = [word.lower() for word in remove_punctuation.split() if word.lower() not in nltk.corpus.stopwords.words('english')]
    
    # Stemming words using PorterStemmer.
    return [stemmer.stem(word) for word in remove_stop]
    
    # NOTE:
    # Below would be the return function without stemming.
    #return [word.lower() for word in remove_punctuation.split() if word.lower() not in nltk.corpus.stopwords.words('english')]

# %%
def to_string(text):
    """
    Function that will convert the items on a list to a string.
    """
    return ' '.join(text)

# %% [markdown]
# ### Loading dataset into a pandas dataframe.

# %%
economic_df = pd.read_csv('Full-Economic-News-DFE-839861.csv', encoding='utf-8')

# %%
new_column_names = ['unit_id', 'golden', 'unit_state', 'trusted_judgments', 'last_judgment_at','positivity', 'positivity_confidence', 'relevance', 'relevance_confidence', 'article_id', 'article_date', 'article_headline', 'positivity_gold', 'relevance_gold', 'article_text']

# %% [markdown]
# #### Text pre-processing.

# %%
economic_df.columns = new_column_names

# %%
economic_df['article_headline'] = economic_df['article_headline'].apply(clean_up_article)

# %%
economic_df['article_text'] = economic_df['article_text'].apply(clean_up_article)

# %%
economic_df['headline_normalized'] = economic_df['article_headline'].apply(process_dataframe_text)

# %%
economic_df['article_normalized'] = economic_df['article_text'].apply(process_dataframe_text)

# %%
economic_df['headline_string'] = economic_df['headline_normalized'].apply(to_string)

# %%
economic_df['article_string'] = economic_df['article_normalized'].apply(to_string)

# %%
economic_df.head()
# Out:
#      unit_id golden unit_state  trusted_judgments    last_judgment_at  \
# 0  842613455  False  finalized                  3  12/5/2015 17:48:27
# 1  842613456  False  finalized                  3  12/5/2015 16:54:25
# 2  842613457  False  finalized                  3  12/5/2015 01:59:03
# 3  842613458  False  finalized                  3  12/5/2015 02:19:39
# 4  842613459  False  finalized                  3  12/5/2015 17:48:27
#
#    positivity  positivity_confidence relevance  relevance_confidence  \
# 0         3.0                 0.6400       yes                 0.640
# 1         NaN                    NaN        no                 1.000
# 2         NaN                    NaN        no                 1.000
# 3         NaN                 0.0000        no                 0.675
# 4         3.0                 0.3257       yes                 0.640
#
#       article_id article_date  \
# 0  wsj_398217788   1991-08-14
# 1  wsj_399019502   2007-08-21
# 2  wsj_398284048   1991-11-14
# 3  wsj_397959018   1986-06-16
# 4  wsj_398838054   2002-10-04
#
#                                     article_headline  positivity_gold  \
# 0              Yields on CDs Fell in the Latest Week              NaN
# 1  The Morning Brief: White House Seeks to Limit ...              NaN
# 2  Banking Bill Negotiators Set Compromise --- Pl...              NaN
# 3  Managers Journal: Sniffing Out Drug Abusers Is...              NaN
# 4  Currency Trading: Dollar Remains in Tight Rang...              NaN
#
#    relevance_gold                                       article_text  \
# 0             NaN  NEW YORK -- Yields on most certificates of dep...
# 1             NaN  The Wall Street Journal OnlineThe Morning Brie...
# 2             NaN  WASHINGTON -- In an effort to achieve banking ...
# 3             NaN  The statistics on the enormous costs of employ...
# 4             NaN  NEW YORK -- Indecision marked the dollars tone...
#
#                                  headline_normalized  \
# 0                    [yield, cd, fell, latest, week]
# 1  [morn, brief, white, hous, seek, limit, child,...
# 2  [bank, bill, negoti, set, compromis, plan, wid...
# 3     [manag, journal, snif, drug, abus, quick, fix]
# 4  [currenc, trade, dollar, remain, tight, rang, ...
#
#                                   article_normalized  \
# 0  [new, york, yield, certif, deposit, offer, maj...
# 1  [wall, street, journal, onlineth, morn, brief,...
# 2  [washington, effort, achiev, bank, reform, sen...
# 3  [statist, enorm, cost, employe, drug, abus, we...
# 4  [new, york, indecis, mark, dollar, tone, trade...
#
#                                      headline_string  \
# 0                          yield cd fell latest week
# 1  morn brief white hous seek limit child insur p...
# 2  bank bill negoti set compromis plan widen bank...
# 3             manag journal snif drug abus quick fix
# 4  currenc trade dollar remain tight rang amid wa...
#
#                                       article_string
# 0  new york yield certif deposit offer major bank...
# 1  wall street journal onlineth morn brief look d...
# 2  washington effort achiev bank reform senat neg...
# 3  statist enorm cost employe drug abus well know...
# 4  new york indecis mark dollar tone trader paus ...

# %% [markdown]
# #### Using TfidfVectorizer.

# %%
vectorized = TfidfVectorizer(max_features=1000, max_df=0.95, min_df=2)

# %%
headline_tf = vectorized.fit_transform(economic_df['headline_string'])

# %%
lda = LatentDirichletAllocation(n_topics=20,
                                max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)

# %%
lda.fit(headline_tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_jobs=1, n_topics=20, perp_tol=0.1, random_state=42,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
def get_top_words(model, feature_names, n_top_words):
    text = ''
    for topic_idx, topic in enumerate(model.components_):
        text = text + " ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]])
    return text

# %%
print("Headline Topics in LDA model:\n")
tf_feature_names = vectorized.get_feature_names()
n_top_words = 20
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Headline Topics in LDA model:
#
# Topic #0:
# plan hous secur time program fed rail seek brief would fight gop buy offer key interest rate studi chairman bank
# Topic #1:
# world nation china loan bank urg donot hill leader law japanes advis let brazil student land stabil us 30 septemb
# Topic #2:
# decemb saturday 1978 1980 toward age deriv note attack treasuri light 12 look april background post special row wait reagan
# Topic #3:
# way boom control america govern face capit counti target option question bid quiet beat buyer weekend problem best take mean
# Topic #4:
# ahead wall street tape report feder suppli roundup money live special journal challeng monday like week middl pain holiday local
# Topic #5:
# save region bet chief ford must cpi sustain name lift bond speech industri risk possibl right race latin greenspan lender
# Topic #6:
# mortgag home fall rate percent yet revers away cours reit increas profit boost price must ralli far dollar euro weigh
# Topic #7:
# stock dow market post gain price digest rise ralli bond trade profit declin drop sale high rate point industri fall
# Topic #8:
# job offic invest area reserv incom financi foreign still help open debat strength find worker first us use dividend fire
# Topic #9:
# recess today nixon burn battl agenda weaken upturn danger gear 3rd blame greenspan seen bush record comput quarter bullish modest
# Topic #10:
# issu greenspan power employ market break rais bigger emerg insight late deflat sourc lead defend ad turmoil panel payrol reason
# Topic #11:
# fund trade us news bad manag talk put go turn japan gap deficit american narrow citi big export risk get
# Topic #12:
# dollar unemploy jobless hit record low board even yen congress level rate card sinc defens expans lowest claim seen old
# Topic #13:
# pay econom polit economi democrat benefit wage va recoveri impact ipo see chang seri canot answer product eye state race
# Topic #14:
# tax bill bush senat presid cut aid dc rule work back vote critic new attack plan war bank obama role
# Topic #15:
# washington deficit billion budget need crisi sunday debt come deal reagan reach labor look peopl what cut agre long right
# Topic #16:
# fed rate inflat economi growth market price say interest rise us consum treasuri end analyst move slow econom stock credit
# Topic #17:
# busi financ outlook review letter win editor book fanni editori montgomeri 50 balanc behind mae audit lag intern yearend big
# Topic #18:
# watch opportun corpor stall 19 drift st press russia might bit us recoveri sale europ near remain home main last
# Topic #19:
# call real one reform steel tri fiscal return hard fix estat effect far md januari man isnot worri final thing

# %% [markdown]
# #### Creating WordCloud for headlines.

# %%
tf_feature_names = vectorized.get_feature_names()
n_top_words = 20
text = get_top_words(lda, tf_feature_names, n_top_words)

# %%
CLOUD_TEXT = text
tags = make_tags(get_tag_counts(CLOUD_TEXT), maxsize=60)
# Out:
# plan
# hous
# secur
# time
# program
# fed
# rail
# seek
# brief
# would
# fight
# gop
# buy
# offer
# key
# interest
# rate
# studi
# chairman
# bankworld
# nation
# china
# loan
# bank
# urg
# donot
# hill
# leader
# law
# japanes
# advis
# let
# brazil
# student
# land
# stabil
# us
# 30
# septembdecemb
# saturday
# 1978
# 1980
# toward
# age
# deriv
# note
# attack
# treasuri
# light
# 12
# look
# april
# background
# post
# special
# row
# wait
# reaganway
# boom
# control
# america
# govern
# face
# capit
# counti
# target
# option
# question
# bid
# quiet
# beat
# buyer
# weekend
# problem
# best
# take
# meanahead
# wall
# street
# tape
# report
# feder
# suppli
# roundup
# money
# live
# special
# journal
# challeng
# monday
# like
# week
# middl
# pain
# holiday
# localsave
# region
# bet
# chief
# ford
# must
# cpi
# sustain
# name
# lift
# bond
# speech
# industri
# risk
# possibl
# right
# race
# latin
# greenspan
# lendermortgag
# home
# fall
# rate
# percent
# yet
# revers
# away
# cours
# reit
# increas
# profit
# boost
# price
# must
# ralli
# far
# dollar
# euro
# weighstock
# dow
# market
# post
# gain
# price
# digest
# rise
# ralli
# bond
# trade
# profit
# declin
# drop
# sale
# high
# rate
# point
# industri
# falljob
# offic
# invest
# area
# reserv
# incom
# financi
# foreign
# still
# help
# open
# debat
# strength
# find
# worker
# first
# us
# use
# dividend
# firerecess
# today
# nixon
# burn
# battl
# agenda
# weaken
# upturn
# danger
# gear
# 3rd
# blame
# greenspan
# seen
# bush
# record
# comput
# quarter
# bullish
# modestissu
# greenspan
# power
# employ
# market
# break
# rais
# bigger
# emerg
# insight
# late
# deflat
# sourc
# lead
# defend
# ad
# turmoil
# panel
# payrol
# reasonfund
# trade
# us
# news
# bad
# manag
# talk
# put
# go
# turn
# japan
# gap
# deficit
# american
# narrow
# citi
# big
# export
# risk
# getdollar
# unemploy
# jobless
# hit
# record
# low
# board
# even
# yen
# congress
# level
# rate
# card
# sinc
# defens
# expans
# lowest
# claim
# seen
# oldpay
# econom
# polit
# economi
# democrat
# benefit
# wage
# va
# recoveri
# impact
# ipo
# see
# chang
# seri
# canot
# answer
# product
# eye
# state
# racetax
# bill
# bush
# senat
# presid
# cut
# aid
# dc
# rule
# work
# back
# vote
# critic
# new
# attack
# plan
# war
# bank
# obama
# rolewashington
# deficit
# billion
# budget
# need
# crisi
# sunday
# debt
# come
# deal
# reagan
# reach
# labor
# look
# peopl
# what
# cut
# agre
# long
# rightfed
# rate
# inflat
# economi
# growth
# market
# price
# say
# interest
# rise
# us
# consum
# treasuri
# end
# analyst
# move
# slow
# econom
# stock
# creditbusi
# financ
# outlook
# review
# letter
# win
# editor
# book
# fanni
# editori
# montgomeri
# 50
# balanc
# behind
# mae
# audit
# lag
# intern
# yearend
# bigwatch
# opportun
# corpor
# stall
# 19
# drift
# st
# press
# russia
# might
# bit
# us
# recoveri
# sale
# europ
# near
# remain
# home
# main
# lastcall
# real
# one
# reform
# steel
# tri
# fiscal
# return
# hard
# fix
# estat
# effect
# far
# md
# januari
# man
# isnot
# worri
# final
# thing

# %%
filename = 'headlines_cloud.png'

# %%
create_tag_image(tags, filename, size=(900, 600), fontname='Lobster')

# %%
chrome_path = 'open -a /Applications/Google\ Chrome.app %s'

# %%
webbrowser.get(chrome_path).open('file://' + os.path.realpath(filename))
# Out:
# True

# %% [markdown]
# #### Creating WordCloud for articles.

# %%
article_tf = vectorized.fit_transform(economic_df['article_string'])

# %%
lda.fit(article_tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_jobs=1, n_topics=20, perp_tol=0.1, random_state=42,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
tf_feature_names = vectorized.get_feature_names()
n_top_words = 20
text = get_top_words(lda, tf_feature_names, n_top_words)

# %%
CLOUD_TEXT = text
tags = make_tags(get_tag_counts(CLOUD_TEXT), maxsize=60)
# Out:
# said
# would
# year
# tax
# bank
# state
# presid
# feder
# econom
# hous
# budget
# percent
# govern
# one
# nation
# new
# rate
# compani
# billion
# usoption
# stock
# index
# gold
# year
# compani
# citi
# global
# canadian
# nasdaq
# fund
# investor
# dec
# correct
# chang
# market
# stockmarket
# name
# close
# sayhome
# treasuri
# consum
# said
# may
# yield
# hous
# indic
# although
# move
# peopl
# price
# govern
# econom
# stock
# commerc
# often
# name
# continu
# bondmr
# provid
# contract
# univers
# econom
# quarter
# cost
# clinton
# design
# school
# fourth
# care
# would
# peopl
# health
# yield
# one
# student
# billion
# pricejapan
# survey
# quarter
# compani
# pay
# japanes
# buyer
# us
# recoveri
# alway
# trade
# week
# govern
# save
# deposit
# consum
# servic
# germani
# would
# bankbank
# trader
# central
# dollar
# effort
# us
# interest
# germani
# currenc
# yesterday
# rais
# struggl
# quickli
# eight
# evid
# rate
# attempt
# billion
# caus
# consumtrillion
# health
# 100
# studi
# spend
# 18
# yield
# issu
# expect
# journal
# jump
# basi
# grew
# bond
# center
# reach
# publish
# privat
# avoid
# interestmillion
# share
# revenu
# cent
# net
# compani
# inc
# earn
# nasdaq
# said
# result
# analyst
# corp
# billion
# profit
# oper
# incom
# rose
# technolog
# earlierfed
# program
# rate
# econom
# inflat
# expect
# economi
# spend
# good
# forecast
# growth
# deal
# next
# minut
# univers
# us
# polici
# statement
# meet
# summerfed
# chairman
# share
# product
# made
# system
# earn
# think
# greenspan
# standard
# use
# nasdaq
# stock
# index
# polici
# oper
# publish
# trade
# lower
# edgbank
# vote
# plan
# compani
# feder
# sen
# regul
# bill
# democrat
# share
# hous
# obama
# reserv
# deal
# republican
# mr
# board
# also
# like
# stockdeficit
# billion
# export
# import
# trade
# commerc
# gap
# depart
# month
# record
# us
# revis
# fiscal
# januari
# decemb
# figur
# total
# august
# secretari
# novembdollar
# currenc
# yen
# japan
# us
# japanes
# euro
# german
# trade
# west
# mark
# central
# germani
# european
# bank
# franc
# tokyo
# foreign
# europ
# traderprofit
# airlin
# price
# oper
# stock
# compani
# market
# million
# year
# expect
# financi
# say
# investor
# rate
# invest
# share
# said
# capit
# us
# economcompani
# foreign
# author
# manag
# ad
# us
# contribut
# market
# limit
# campaign
# insur
# make
# invest
# china
# think
# end
# come
# allow
# protect
# rathermortgag
# loan
# lender
# card
# home
# rate
# credit
# borrow
# buyer
# interest
# lend
# bank
# payment
# charg
# fee
# 30year
# consum
# banker
# fix
# monthlistock
# market
# price
# rate
# percent
# point
# averag
# index
# new
# said
# dow
# industri
# report
# york
# share
# year
# bond
# gain
# trade
# rosegold
# futur
# contract
# author
# commod
# said
# price
# dollar
# mr
# new
# trade
# us
# york
# market
# trader
# regul
# ralli
# exchang
# depress
# buyquarter
# gdp
# fourth
# save
# survey
# growth
# economist
# capit
# real
# year
# expect
# go
# busi
# rate
# stronger
# recess
# event
# biggest
# would
# economiprice
# health
# fund
# consum
# still
# year
# januari
# market
# month
# june
# could
# stock
# work
# sale
# american
# inflat
# product
# plung
# invest
# last

# %%
filename = 'articles_cloud.png'

# %%
create_tag_image(tags, filename, size=(900, 600), fontname='Lobster')

# %%
chrome_path = 'open -a /Applications/Google\ Chrome.app %s'

# %%
webbrowser.get(chrome_path).open('file://' + os.path.realpath(filename))
# Out:
# True
